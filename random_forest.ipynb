# %%
from sklearn import datasets,neighbors
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
digits = datasets.load_digits()
df = pd.DataFrame(digits['data'])
train_x = df
train_y = digits['target']

# %%
r_forest_classifier = RandomForestClassifier()

# %%
r_forest_classifier.fit(train_x, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# Funciones para la visualización de información

# %%
def show_image(index):
    plt.imshow(digits['images'][index], cmap='Greys_r')
    plt.show()

def test_case(index):
    show_image(index)
    test = np.array(digits['data'][index]).reshape(1,-1)
    number_predicted = r_forest_classifier.predict(test)
    print(digits['target_names'][number_predicted[0]])

# %%
test_case(1650)
# Out:
# 5

# %%
score = r_forest_classifier.score(train_x, train_y)
print(f"Score Random Forest: {score}")
# Out:
# Score Random Forest: 1.0

# %%
import PIL 
from sklearn.datasets import fetch_lfw_people

lw_faces = fetch_lfw_people()

# %%
for label in lw_faces.target_names:
    print(label)
# Out:
# orth
# Peter Holmberg
# Peter Hunt
# Peter Lundgren
# Peter Mackay
# Peter Mansbridge
# Peter Max
# Peter Medgyessy
# Peter Mugyeni
# Peter Mullan
# Peter OToole
# Peter Rasch
# Peter Rasmussen
# Peter Schultz
# Peter Sejna
# Peter Shaw
# Peter Struck
# Peter Ueberroth
# Petria Thomas
# Petro Symonenko
# Pham Sy Chien
# Pham Thi Mai Phuong
# Phan Van Khai
# Pharrell Williams
# Phil Bennett
# Phil Bredesen
# Phil Cline
# Phil Cullen
# Phil Donahue
# Phil Gramm
# Phil Jackson
# Phil Johnson
# Phil McGraw
# Phil Mickelson
# Phil Morris
# Phil Vassar
# Philip Cummings
# Philip Murtaugh
# Philip Zalewski
# Philippe Gagnon
# Philippe Noiret
# Phillip Fulmer
# Phillip Seymor Hoffmann
# Phillipe Comtois
# Phillips Idowu
# Phoenix Chang
# Picabo Street
# Pier Ferdinando Casini
# Pierce Brosnan
# Pierre Boulanger
# Pierre Gagnon
# Pierre Lacroix
# Pierre Pettigrew
# Pierre Png
# Pierre Van Hooijdonk
# Piers Sellers
# Pieter Bouw
# Pilar Montenegro
# Pinar del Rio
# Pio Laghi
# ...

# %%
def show_Rostro(index, source):
    plt.imshow(source['images'][index], cmap='Greys_r')
    plt.show()

# %%
show_Rostro(3250,lw_faces)

# %%
lw_faces.target[3250]
# Out:
# 5619

# %%
lw_faces.target_names[5619]
# Out:
# 'Will Smith'

# %%
lw_faces
# Out:
# {'data': array([[ 34.      ,  29.333334,  22.333334, ...,  14.666667,  16.      ,
#           14.      ],
#         [158.      , 160.66667 , 169.66667 , ..., 138.66667 , 135.66667 ,
#          130.33333 ],
#         [ 76.666664,  81.      ,  87.666664, ..., 191.66667 , 145.33333 ,
#           66.      ],
#         ...,
#         [ 38.333332,  41.666668,  55.      , ...,  66.      ,  63.333332,
#           54.666668],
#         [ 16.666666,  24.333334,  60.333332, ..., 219.      , 144.      ,
#           69.      ],
#         [ 58.333332,  48.      ,  20.      , ..., 116.      , 105.666664,
#          143.66667 ]], dtype=float32),
#  'images': array([[[ 34.      ,  29.333334,  22.333334, ...,  20.      ,
#            26.      ,  31.      ],
#          [ 37.333332,  32.      ,  25.333334, ...,  21.      ,
#            27.      ,  32.      ],
#          [ 33.333332,  32.      ,  40.333332, ...,  23.333334,
#            28.666666,  35.666668],
#          ...,
# ...

# %%
df = pd.DataFrame(lw_faces.data)
df.head()
# Out:
#          0           1           2           3           4           5     \
# 0   34.000000   29.333334   22.333334   22.000000   26.000000   29.333334
# 1  158.000000  160.666672  169.666672  168.666672  162.666672  161.000000
# 2   76.666664   81.000000   87.666664  108.000000  135.666672  151.333328
# 3   11.333333   10.666667   11.333333   12.666667   13.666667   15.000000
# 4   32.333332   31.333334   31.333334   33.666668   33.000000   32.333332
#
#          6           7           8           9     ...        2904  \
# 0   38.333332   68.333336   96.666664  117.333336  ...   26.666666
# 1  158.000000  162.666672  163.000000  159.333328  ...  218.000000
# 2  154.666672  163.333328  167.333328  171.333328  ...  176.666672
# 3   15.333333   13.000000   13.000000   14.000000  ...  121.333336
# 4   36.333332   43.333332   42.666668   36.000000  ...   19.333334
#
#          2905        2906        2907        2908        2909        2910  \
# ...

# %%
data_x = df
data_y = lw_faces['target']

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.20)

# %%
train_x
# Out:
#              0           1           2           3           4           5     \
# 2437    17.666666   27.000000   29.666666   10.000000    5.000000   10.333333
# 2206    30.333334   28.666666   72.000000  128.666672  147.000000  144.333328
# 4288    28.666666   44.333332   54.333332   64.333336   79.333336   98.000000
# 3744   111.666664   86.333336   68.000000   79.333336   87.666664   90.333336
# 3841    70.333336   89.666664  108.333336  126.333336  139.333328  143.333328
# ...           ...         ...         ...         ...         ...         ...
# 10790   70.666664   56.666668   43.000000   40.333332   39.666668   39.333332
# 5519    93.333336   90.333336   80.666664   78.000000   77.000000   86.666664
# 4614    42.000000   62.000000   64.666664   55.666668   45.333332   39.666668
# 5550    29.000000   40.000000   62.333332   96.333336  133.333328  166.666672
# 1744   153.000000  153.333328  152.333328  155.000000  154.000000  150.666672
#
# ...

# %%
test_x
# Out:
#              0           1           2           3           4           5     \
# 10035   18.333334   22.000000   24.666666   25.333334   26.333334   27.000000
# 266     57.666668   43.000000   33.666668   29.000000   42.000000   70.666664
# 1539     6.666667    5.666667    4.666667    5.000000    5.666667    6.666667
# 6441   168.000000  173.333328  179.666672  180.000000  183.666672  188.000000
# 12887  112.000000  112.333336  117.333336  116.000000  113.666664  111.666664
# ...           ...         ...         ...         ...         ...         ...
# 5728    98.666664  111.666664  103.000000   82.666664   87.333336   85.000000
# 11245   91.000000   87.333336   75.666664   75.666664   96.000000  116.000000
# 10824   88.000000  103.666664  123.666664  139.000000  141.000000  140.000000
# 11994  179.666672  180.333328  180.666672  171.333328  160.333328  158.333328
# 4113    88.000000   99.000000  117.000000  135.333328  150.000000  157.666672
#
# ...

# %% [markdown]
# Neigbors

# %%
k_nearest_classifier = neighbors.KNeighborsClassifier(10)
k_nearest_classifier.fit(test_x, test_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
score = k_nearest_classifier.score(test_x, test_y)
print(f"Score Random Forest: {score}")
# Out:
# Score Random Forest: 0.18095957687948622

# %% [markdown]
# Forest

# %%
r_forest_classifier2 = RandomForestClassifier(n_estimators=25)

# %%
r_forest_classifier2.fit(test_x, test_y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=25,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
score2 = r_forest_classifier2.score(test_x, test_y)
print(f"Score Random Forest: {score2}")
# Out:
# Score Random Forest: 1.0
